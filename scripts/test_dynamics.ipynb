# %%
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from irbfn_mpc.dynamics import integrate_st_mult
import jax.numpy as jnp
import jax

# %%
dyn_params = jnp.array([1.0, 1.0489, 0.04712, 0.15875, 0.17145, 5.0, 5.0, 0.074, 0.1, 3.2, 9.51, 0.4189, 7.0])

# %%
states = jnp.zeros((10, 7))
u = -10 * jnp.ones((10, 10))
x_and_u = jnp.hstack((states, u))

# %%
all_states = integrate_st_mult(x_and_u, dyn_params)
# Out:
# states in integration nan
# states in integration nan
# states in integration nan
# states in integration nan
# states in integration nan
# states in integration nan
# states in integration nan
# states in integration nan
# states in integration nan
# states in integration nan
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# states in integration -0.0
# ...

# %%
all_states
# Out:
# Array([[[ 0.        ,  0.        , -0.32000002, -0.95100003,
#           0.        ,  0.        ,  0.        ],
#         [-0.09510001,  0.        , -0.64000005, -1.9020001 ,
#           0.09544256,  0.        ,  0.        ],
#         [-0.28443438, -0.01812563, -0.96000004, -2.8530002 ,
#           0.35191524,  0.        ,  0.        ],
#         [-0.55224955, -0.1164675 , -1.2800001 , -3.8040001 ,
#           0.73662424,  0.        ,  0.        ],
#         [-0.8340273 , -0.3720169 , -1.6000001 , -4.755     ,
#           1.2495697 ,  0.        ,  0.        ]],
#
#        [[ 0.        ,  0.        , -0.32000002, -0.95100003,
#           0.        ,  0.        ,  0.        ],
#         [-0.09510001,  0.        , -0.64000005, -1.9020001 ,
#           0.09544256,  0.        ,  0.        ],
#         [-0.28443438, -0.01812563, -0.96000004, -2.8530002 ,
#           0.35191524,  0.        ,  0.        ],
#         [-0.55224955, -0.1164675 , -1.2800001 , -3.8040001 ,
# ...
